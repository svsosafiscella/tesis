# %%
import psrchive
import matplotlib.pyplot as plt
import numpy as np
import glob
import subprocess

# %%
#Load all PFD files in folder
ant = 'A2'                                               # antena usada (A1 o A2)
timing_folder = './' + str(ant) + '/'
pfd_files = glob.glob('*pfd')

#print(pfd_files)

# %%
print(pfd_files[0])
# Out:
# prepfold_20191111_023127_PSR_0437-4715.pfd

# %%
archive = psrchive.Archive_load(pfd_files[0])
data = archive.get_data()
data.shape
# Out:
# (60, 1, 64, 1024)

# %%
# Convert PFD files to PSRFITS
for pfd in pfd_files:
    archive = psrchive.Archive_load(pfd)
    data = archive.get_data()
    print(data.shape)
    
    archive.bscrunch_to_nbin(512)
    data2 = archive.get_data()
    print(data2.shape)
    archive.unload('./A2_512/' + str(pfd))
# Out:
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (128, 1, 64, 1024)
# (128, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 512)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 512)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# (60, 1, 64, 512)
# (60, 1, 64, 1024)
# ...
